# %% [markdown]
# # Object Storage in Data Science Experience - Python #
# ##### <font color=darkblue>How to import/export, read/write files (.csv, .txt, etc) in DSX Notebooks using python</font>
#
# ***

# %% [markdown]
# ### Step 1 - Adding a file to your Object Storage

# %% [markdown]
# <font color=green><b> - Navigate to your Object Storage</b></font>
#
# ![ObjectStorage.png](attachment:ObjectStorage.png)
#
# ***
# <font color=green><b> - Select your container</b></font>
#
# ![Containers.png](attachment:Containers.png)
#
# ***
# <font color=green><b> - Add your file (you can add an empty file or one with your saved data)</b></font>
#
# ![AddFile.png](attachment:AddFile.png)
#
# ***
# <font color=green><b> - You should see a file under your container</b></font>
#
# ![AddedFile.png](attachment:AddedFile.png)

# %% [markdown]
# ### Step 2 - Adding code cells in your notebook

# %%
ls
# Out:
# db_2017_05_24_intercom_processor_logs_20170628_094032.log
# db_2017_05_24_intercom_processor_logs_20170628_094304.log
# db_2017_05_24_intercom_processor_logs_20170628_094326.log
# db_2017_05_24_intercom_processor_logs_20170628_094457.log
# db_2017_05_24_unimp_convos.txt
# db_2017_05_24_unsupported_convos.txt
# GoogleCodeJam.txt
# intercom_processor_logs_test.log
# mylog.log
# test2.csv
# test3.csv
# test_download.txt
# unimp_convos_alchemy_db_2017_03_07.txt
